# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\Jawad\.wdm\drivers\chromedriver\win32\98.0.4758.80\chromedriver.exe] found in cache

# %%
driver.get('https://www.seleniumhq.org')

# %%
driver.find_element(By)
# Out:
# C:\Users\Jawad\AppData\Local\Temp\ipykernel_3280\1027247922.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text('Download')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 driver.find_element_by_link_text('Download')
#
# File ~\Desktop\python\selenium\third\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:568, in WebDriver.find_element_by_link_text(self, link_text)
#     546 """
#     547 Finds an element by link text.
#     548
#    (...)
#     561         element = driver.find_element_by_link_text('Sign In')
#     562 """
#     563 warnings.warn(
#     564     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     565     DeprecationWarning,
#     566     stacklevel=2,
#     567 )
# --> 568 return self.find_element(by=By.LINK_TEXT, value=link_text)
#
# File ~\Desktop\python\selenium\third\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:1244, in WebDriver.find_element(self, by, value)
#    1241     by = By.CSS_SELECTOR
#    1242     value = '[name="%s"]' % value
# -> 1244 return self.execute(Command.FIND_ELEMENT, {
#    1245     'using': by,
#    1246     'value': value})['value']
#
# File ~\Desktop\python\selenium\third\venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     422 response = self.command_executor.execute(driver_command, params)
#     423 if response:
# --> 424     self.error_handler.check_response(response)
#     425     response['value'] = self._unwrap_value(
#     426         response.get('value', None))
#     427     return response
#
# File ~\Desktop\python\selenium\third\venv\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"Download"}
#   (Session info: chrome=98.0.4758.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00417AC3+2587331]
# 	Ordinal0 [0x003AADD1+2141649]
# 	Ordinal0 [0x002A3BB8+1063864]
# 	Ordinal0 [0x002D01CE+1245646]
# 	Ordinal0 [0x002D03CB+1246155]
# 	Ordinal0 [0x002FA612+1418770]
# 	Ordinal0 [0x002E86D4+1345236]
# 	Ordinal0 [0x002F8A0A+1411594]
# 	Ordinal0 [0x002E84A6+1344678]
# 	Ordinal0 [0x002C53F6+1201142]
# 	Ordinal0 [0x002C62E6+1204966]
# 	GetHandleVerifier [0x005BDF22+1680738]
# 	GetHandleVerifier [0x00670DBC+2413564]
# 	GetHandleVerifier [0x004AD151+563089]
# 	GetHandleVerifier [0x004ABF13+558419]
# 	Ordinal0 [0x003B081E+2164766]
# 	Ordinal0 [0x003B5508+2184456]
# 	Ordinal0 [0x003B5650+2184784]
# 	Ordinal0 [0x003BF5BC+2225596]
# 	BaseThreadInitThunk [0x7528FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77187A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77187A6E+238]
